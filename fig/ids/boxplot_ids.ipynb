# %% [markdown]
# ### 箱线图 -- 内在维度

# %%
import matplotlib.pyplot as plt
import numpy as np

datasets = ['AC', 'spam', 'a9a', 'ImageNet-10', 'Cifar-10', 'aloi', 'USPS', 'mnist100000', 'COIL20', 'RCV1', 'gisette', 'YaleB']

id_values = [
    [1.6086, 1.8631, 1.9936, 2.1019, 2.4035], # AC
    [1.1560, 4.1734, 5.8623, 7.4223, 10.2558], # spam
    [4.8367, 7.8190, 11.9058, 18.8979, 40.1874], # a9a
    [1.4570, 2.0552, 2.4476, 2.9232, 4.0482], # ImageNet-10
    [2.9871, 4.2496, 5.1143, 6.1216, 8.7299], # Cifar-10
    [1.8839, 3.6099, 5.2469, 7.5503, 12.5963], # aloi
    [4.9863, 8.1502, 10.2903, 12.8446, 19.4479], # USPS
    [7.1811, 10.7332, 12.8112, 15.2918, 22.0571], # mnist100000
    [1.3538, 2.8923, 5.1846, 6.4853, 9.0803], # COIL20
    [6.2602, 17.5700, 27.1060, 37.9601, 59.5611], # RCV1
    [24.4394, 32.6207, 39.0754, 46.4645, 62.0298], # gisette
    [8.3265, 11.7109, 14.7230, 18.6756, 28.3022] # YaleB
]

plt.figure(figsize=(12, 6))
plt.boxplot(id_values, labels=datasets)

plt.title('Estimated IDs for datasets using TLE with k = 50')
plt.ylabel('ID')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
plt.savefig("boxplot_dataset_ids.svg", format="svg")

# %%
import matplotlib.pyplot as plt
import numpy as np

datasets = ['AC', 'spam', 'a9a', 'ImageNet-10', 'Cifar-10', 'aloi', 'USPS', 'mnist100000', 'COIL20', 'RCV1', 'gisette', 'YaleB']

id_values = [
    [1.6086, 1.8631, 1.9936, 2.1019, 2.4035], # AC
    [1.0867, 3.2142, 4.3411, 5.4543, 7.4323], 
    [4.1979, 5.7244, 6.8465, 8.1561, 10.9422], 
    [1.5148, 2.0869, 2.4843, 2.9600, 4.2429], 
    [3.0085, 4.2828, 5.1271, 6.1221, 8.5799], 
    [1.6316, 3.1133, 4.4382, 6.1989, 9.9261], 
    [4.0981, 6.6363, 8.1918, 9.9905, 14.8662], 
    [6.4113, 9.5840, 11.4927, 13.7758, 19.7979], 
    [1.2800, 2.6870, 4.9052, 6.0874, 8.5059], 
    [4.9414, 12.6380, 18.4188, 24.9157, 35.1329], 
    [19.9164, 26.5828, 31.6927, 37.5179, 49.8578], 
    [6.2014, 8.4947, 10.4818, 12.8784, 19.3149]
]

plt.figure(figsize=(12, 6))
plt.boxplot(id_values, labels=datasets)

plt.title('Estimated IDs for datasets using TLE with k = 50')
plt.ylabel('ID')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
plt.savefig("boxplot_dr_dataset_ids.svg", format="svg")
