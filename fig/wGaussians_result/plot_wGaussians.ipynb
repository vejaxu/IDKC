# %% [markdown]
# ### wGaussians -- NMI

# %%
import matplotlib.pyplot as plt

# 示例数据集
x_labels = ['1', '2', '3', '4', '5', '10', '50', '100', '200', '500', '1000', '2000', '4000']
method1 = [0.3321, 0.7639, 0.9373, 0.9748, 0.9836, 0.9909, 0.9931, 0.9717, 0.9705, 0.9597, 0.9271, 0.9071, 0.9182]
method2 = [0, 0.9698, 0.9918, 0.9968, 1, 1, 1, 1, 0.4005, 0.3728, 0, 0, 0]
method3 = [0.2333, 0.2767, 0.1868, 0.2671, 0.231, 0.4559, 0.6591, 0.5598, 0.3399, 0.1878]

# 创建折线图
plt.figure(figsize=(10, 6))
plt.plot(x_labels, method1, marker='o', label='IDKC', color='b')
plt.plot(x_labels, method2, marker='s', label='DCV', color='g')
plt.plot(x_labels, method3, marker='^', label='DECCS', color='r')

# 添加标题和标签
plt.title('NMI')
plt.xlabel('Dimension')
plt.ylabel('NMI')

# 添加图例|
plt.legend()

# 显示网格
plt.grid()

# 显示图形
plt.savefig("plot_wGaussians_NMI.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### wGaussians -- ARI

# %%
import matplotlib.pyplot as plt

# 示例数据集
x_labels = ['1', '2', '3', '4', '5', '10', '50', '100', '200', '500', '1000', '2000', '4000']
method1 = [0.231, 0.7977, 0.9642, 0.988, 0.9921, 0.9969, 0.9976, 0.9874, 0.9871, 0.9809, 0.9598, 0.9451, 0.9536]
method2 = [0, 0.9698, 0.9918, 0.9968, 1, 1, 1, 1, 0.4004, 0.3726, 0, 0, 0]
method3 = [0.1546, 0.2801, 0.1549, 0.2385, 0.2063, 0.4596, 0.7232, 0.5768, 0.3477, 0.1687]

# 创建折线图
plt.figure(figsize=(10, 6))
plt.plot(x_labels, method1, marker='o', label='IDKC', color='b')
plt.plot(x_labels, method2, marker='s', label='DCV', color='g')
plt.plot(x_labels, method3, marker='^', label='DECCS', color='r')

# 添加标题和标签
plt.title('NMI')
plt.xlabel('Dimension')
plt.ylabel('NMI')

# 添加图例
plt.legend()

# 显示网格
plt.grid()

# 显示图形
plt.savefig("plot_wGaussians_ARI.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### wGaussians_v1_16_v2_9 NMI

# %%
import matplotlib.pyplot as plt

# 示例数据集
x_labels = ['1', '5', '10', '50', '100', '200', '500', '1000', '2000', '4000']
method1 = [0.3107, 0.9826, 0.9943, 0.9823, 0.9744, 0.9325, 0.8652, 0.9417, 0.913, 0.899]
method2 = [0, 1, 1, 0.0018, 0.1751, 0, 0, 0, 0, 0]
method3 = [0.265, 0.1619, 0.1651, 0.2314, 0.2155, 0.457, 0.4544, 0.3546, 0.4185, 0.1619]

# 创建折线图
plt.figure(figsize=(10, 6))
plt.plot(x_labels, method1, marker='o', label='IDKC', color='b')
plt.plot(x_labels, method2, marker='s', label='DCV', color='g')
plt.plot(x_labels, method3, marker='^', label='DECCS', color='r')

# 添加标题和标签
plt.title('NMI')
plt.xlabel('Dimension')
plt.ylabel('NMI')

# 添加图例|
plt.legend()

# 显示网格
plt.grid()

# 显示图形
plt.savefig("plot_wGaussians_V1_16_V2_9_NMI.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### wGaussians_v1_16_v2_9 ARI

# %%
import matplotlib.pyplot as plt

# 示例数据集
x_labels = ['1', '5', '10', '50', '100', '200', '500', '1000', '2000', '4000']
method1 = [0.208, 0.9921, 0.9979, 0.993, 0.9892, 0.9646, 0.9056, 0.9704, 0.9515, 0.9405]
method2 = [0, 1, 1, 0.0016, 0.175, 0, 0, 0, 0, 0]
method3 = [0.2049, 0.149, 0.1416, 0.2013, 0.2, 0.4644, 0.4921, 0.3762, 0.4366, 0.136]

# 创建折线图
plt.figure(figsize=(10, 6))
plt.plot(x_labels, method1, marker='o', label='IDKC', color='b')
plt.plot(x_labels, method2, marker='s', label='DCV', color='g')
plt.plot(x_labels, method3, marker='^', label='DECCS', color='r')

# 添加标题和标签
plt.title('ARI')
plt.xlabel('Dimension')
plt.ylabel('ARI')

# 添加图例
plt.legend()

# 显示网格
plt.grid()

# 显示图形
plt.savefig("wGaussians_v1_16_v2_9_ARI.png", dpi=300, bbox_inches='tight')
plt.show()
